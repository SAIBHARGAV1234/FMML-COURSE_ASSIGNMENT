# %% [markdown]
# <a href="https://colab.research.google.com/github/SAIBHARGAV1234/FMML-COURSE_ASSIGNMENT/blob/main/Copy_of_FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-05 06:36:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   358MB/s    in 0.2s
#
# 2023-06-05 06:36:41 (358 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29905  1711.00305v1  The development of high-dimensional generative...    cs
# 21959   1007.2450v1  Distributions over permutations arise in appli...  stat
# 2274   1712.07822v2  Learning algorithms for implicit generative mo...  stat
# 39631  1610.10042v2  SUMMARY : We developed a user-friendly softwar...    cs
# 207    1612.04357v4  In this paper, we propose a novel generative m...    cs
# ...             ...                                                ...   ...
# 11970  1705.07384v1  We present a new approach to the problems of e...  stat
# 21545   1004.3101v1  In this paper we formulate in general terms an...  stat
# 24759   1411.5319v2  In this work, we propose and address a new com...    cs
# 173    1801.01423v2  Catastrophic forgetting occurs when a neural n...    cs
# 3947   cs/0601129v1  This paper presents a review of instantaneousl...    cs
#
#                                                    title  year  \
# 29905  Multi-View Data Generation Without View Superv...  2017
# 21959             Directional Statistics on Permutations  2010
# 2274   Geometrical Insights for Implicit Generative M...  2017
# 39631  ConfocalGN : a minimalistic confocal image sim...  2016
# 207              Stacked Generative Adversarial Networks  2016
# ...                                                  ...   ...
# 11970            Balanced Policy Evaluation and Learning  2017
# 21545  Strong Consistency of Prototype Based Clusteri...  2010
# 24759  Fashion Apparel Detection: The Role of Deep Co...  2014
# 173    Overcoming catastrophic forgetting with hard a...  2018
# 3947             Instantaneously Trained Neural Networks  2006
#
#                                                 keywords
# 29905  [development, dimensional, generative, introdu...
# 21959  [distributions, permutations, applications, in...
# 2274   [algorithms, generative, distribution, distrib...
# 39631  [developed, synthetic, microscopy, specified, ...
# 207    [generative, generative, adversarial, hierarch...
# ...                                                  ...
# 11970  [evaluating, personalized, observational, deci...
# 21545  [formulate, consistency, empirical, minimisati...
# 24759  [detection, detection, important, applications...
# 173    [catastrophic, forgetting, information, subseq...
# 3947   [instantaneously, classification, applications...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29905    [development, dimensional, generative, introdu...
# 21959    [distributions, permutations, applications, in...
# 2274     [algorithms, generative, distribution, distrib...
# 39631    [developed, synthetic, microscopy, specified, ...
# 207      [generative, generative, adversarial, hierarch...
#                                ...
# 21715    [developed, efficient, algorithm, likelihood, ...
# 22236    [statistical, implementation, splitting, alter...
# 37009    [management, autonomous, potential, transport,...
# 713      [development, available, workplace, neverthele...
# 35132    [information, retrieval, multimedia, coputatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8775 words.
# Out of those 4563 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7bad848a-b3ff-43f0-ab4e-13008e10cd8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bad848a-b3ff-43f0-ab4e-13008e10cd8b")) {                    Plotly.newPlot(                        "7bad848a-b3ff-43f0-ab4e-13008e10cd8b",                        [{"x":["introduction","disentangled","approaches","particular","conditional","distribution","development","independent","therefore","intrinsic","effectiveness","describing","different","corresponding","generation","attributes","demonstrate","variations","underlying","variational","dimensional","generalize","structured","realistic","represents","categorical","assumption","generative","observation","potentially","experiment","supervision","adversarial","generating","categories","projections","instances","densities","directional","inference","permutation","establishing","probability","embedding","demonstration","considered","impractical","procedure","factorial","polynomial","difficulty","developed","definition","permutations","statistics","continuous","framework","distributions","applications","multinomial","representation","hypersphere","criterion","surprising","differences","establish","parametrization","including","discrepancy","wasserstein","guarantees","distances","algorithms","geometrical","approximate","parametric","convergence","generator","geometries","interesting","nonconvex","arbitrary","synthetic","distributed","availability","implementation","specified","robustness","illustrate","procedures","characteristics","simulator","parameters","minimalistic","microscopy","discriminator","representations","encourages","hierarchical","gradually","introduce","leveraging","represent","independently","inception","information","encourage","introduced","maximizes","conditioned","decomposes","discriminative","uncertainties","inspection","hierarchy","artificial","preserving","observations","available","stochastic","randomised","functions","generalisation","augmentation","technique","overfitting","effectively","distortions","practices","augmented","expansion","constructed","efficient","constraint","construct","segmented","effective","redundant","overcomes","partitioning","dimensions","neighborhood","structure","clustering","requirement","generated","specifically","computation","consequently","situation","seemingly","subsequently","generates","additional","automatically","occurring","previously","generally","beautiful","identified","vectorial","straightforward","collections","relationship","meaningfully","collection","generalization","traditional","embeddings","representing","reproducing","techniques","accomplish","experimental","prediction","resources","restricted","complexity","typically","mechanism","sequences","classical","preferred","attention","symmetric","regularization","popularity","satisfies","considerable","knowledge","regression","compressed","necessary","completion","parameter","semidefinite","conditions","simplicity","estimation","tomography"],"y":[26,8,430,271,121,213,113,122,166,56,199,32,744,118,138,58,560,75,114,50,175,58,103,61,35,17,55,118,53,53,72,47,112,105,65,20,96,11,15,219,13,9,161,111,14,129,8,115,2,57,45,197,39,5,63,110,515,109,435,4,346,2,45,13,54,43,6,234,11,3,82,28,584,6,113,40,125,32,7,51,6,78,121,102,22,140,43,92,73,42,101,18,243,2,14,18,238,10,89,19,320,56,133,37,12,704,20,150,13,13,11,94,16,13,25,122,42,71,296,126,3,221,9,18,249,32,124,14,10,46,20,60,416,79,78,22,257,15,8,13,39,32,311,145,33,158,175,142,22,34,10,31,56,107,197,14,102,60,1,40,4,24,26,62,4,75,115,170,81,82,8,374,15,397,214,69,47,249,112,108,97,98,16,143,16,71,18,8,36,367,122,25,82,38,106,12,122,15,201,27],"type":"bar"},{"x":["introduction","disentangled","approaches","particular","conditional","distribut ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4563,), (4563, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8125

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 1.0);'>Inflection</span> <span style=''>system</span> <span style=''>of</span> <span style=''>a</span> <span style=''>language</span> <span style=''>as</span> <span style=''>a</span> <span style=''>complex</span> <span style=''>network</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inflection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>synthetic</span> <span style=''>language</span> <span style=''>using</span> <span style=''>Latin</span> <span style=''>as</span> <span style=''>an</span> <span style=''>example</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bipartite</span> <span style=''>graph</span> <span style=''>in</span> <span style=''>which</span> <span style=''>one</span> <span style=''>group</span> <span style=''>of</span> <span style=''>vertices</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correspond</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>headwords</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style=''>group</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inflected</span> <span style=''>forms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encountered</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style=''>text</span> <span style=''>Each</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inflected</span> <span style=''>form</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3142857142857144);'>connected</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>headword</span> <span style=''>which</span> <span style=''>in</span> <span style=''>some</span> <span style=''>cases</span> <span style=''>in</span> <span style=''>non</span> <span style=''>unique</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resulting</span> <span style=''>sparse</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>decomposes</span> <span style=''>into</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3142857142857144);'>connected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>to</span> <span style=''>be</span> <span style=''>called</span> <span style=''>word</span> <span style=''>groups</span> <span style=''>We</span> <span style=''>then</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>the</span> <span style=''>word</span> <span style=''>group</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>coverage</span> <span style=''>curves</span> <span style=''>of</span> <span style=''>selected</span> <span style=''>Latin</span> <span style=''>texts</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>inflection</span> <span style=''>graph</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Plea</span> <span style=''>for</span> <span style=''>Neutral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Comparison</span> <span style=''>Studies</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Computational</span> <span style=''>Sciences</span> <br/><br/><span style=''>In</span> <span style=''>a</span> <span style=''>context</span> <span style=''>where</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>articles</span> <span style=''>are</span> <span style=''>devoted</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>development</span> <span style=''>of</span> <span style=''>new</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>studies</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appreciated</span> <span style=''>by</span> <span style=''>readers</span> <span style=''>but</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surprisingly</span> <span style=''>given</span> <span style=''>poor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consideration</span> <span style=''>by</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>scientific</span> <span style=''>journals</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>connection</span> <span style=''>with</span> <span style=''>recent</span> <span style=''>articles</span> <span style=''>on</span> <span style=''>over</span> <span style=''>optimism</span> <span style=''>and</span> <span style=''>epistemology</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bioinformatics</span> <span style=''>this</span> <span style=''>letter</span> <span style=''>stresses</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>importance</span> <span style=''>of</span> <span style=''>neutral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>studies</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establishment</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>standards</span> <span style=''>by</span> <span style=''>drawing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parallels</span> <span style=''>with</span> <span style=''>clinical</span> <span style=''>research</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Common</span> <span style=''>Voting</span> <span style=''>Rules</span> <span style=''>as</span> <span style=''>Maximum</span> <span style='background-color:rgba(255, 0, 0, 0.49193548387096775);'>Likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.7052631578947369);'>Estimators</span> <br/><br/><span style=''>Voting</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style=''>general</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3469387755102041);'>preference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>aggregation</span> <span style=''>A</span> <span style=''>voting</span> <span style=''>rule</span> <span style=''>takes</span> <span style=''>as</span> <span style=''>input</span> <span style=''>every</span> <span style=''>voters</span> <span style=''>vote</span> <span style=''>(typically</span> <span style=''>a</span> <span style=''>ranking</span> <span style=''>of</span> <span style=''>the</span> <span style=''>alternatives)</span> <span style=''>and</span> <span style=''>produces</span> <span style=''>as</span> <span style=''>output</span> <span style=''>either</span> <span style=''>just</span> <span style=''>the</span> <span style=''>winning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>or</span> <span style=''>a</span> <span style=''>ranking</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternatives</span> <span style=''>One</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>view</span> <span style=''>of</span> <span style=''>voting</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>There</span> <span style=''>exists</span> <span style=''>a</span> <span style=''>correct</span> <span style=''>outcome</span> <span style=''>(winnerranking)</span> <span style=''>and</span> <span style=''>each</span> <span style=''>voters</span> <span style=''>vote</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>a</span> <span style=''>noisy</span> <span style='background-color:rgba(0, 255, 0, 0.7446808510638299);'>perception</span> <span style=''>of</span> <span style=''>this</span> <span style=''>correct</span> <span style=''>outcome</span> <span style=''>If</span> <span style=''>we</span> <span style=''>are</span> <span style=''>given</span> <span style=''>the</span> <span style=''>noise</span> <span style=''>model</span> <span style=''>then</span> <span style=''>for</span> <span style=''>any</span> <span style=''>vector</span> <span style=''>of</span> <span style=''>votes</span> <span style=''>we</span> <span style=''>can</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Feature</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Graphs</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>general</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>called</span> <span style=''>DeepGL</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>deep</span> <span style=''>node</span> <span style=''>and</span> <span style=''>edge</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>from</span> <span style=''>large</span> <span style=''>(attributed)</span> <span style=''>graphs</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>DeepGL</span> <span style=''>begins</span> <span style=''>by</span> <span style=''>deriving</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>base</span> <span style=''>features</span> <span style=''>(eg</span> <span style=''>graphlet</span> <span style=''>features)</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>learns</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>layered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hierarchical</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>where</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successive</span> <span style=''>layer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>leverages</span> <span style=''>the</span> <span style=''>output</span> <span style=''>from</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>layer</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>features</span> <span style=''>of</span> <span style=''>a</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>Contrary</span> <span style=''>to</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>DeepGL</span> <span style=''>learns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>(each</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>a</span> <span style=''>feature)</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>across</span> <span style=''>networks</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>useful</span> <span style=''>for</span> <span style=''>graph</span> <span style=''>based</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>Moreover</span> <span style=''>DeepGL</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>supports</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributed</span> <span style=''>graphs</span> <span style=''>learns</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>features</span> <span style=''>and</span> <span style=''>is</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>(by</span> <span style=''>learning</span> <span style=''>sparse</span> <span style=''>feature</span> <span style=''>vectors)</span> <span style=''>In</span> <span style=''>addition</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10114777618364419)
# 	evaluation (0.10401721664275466)
# 	experimental (0.14239598278335724)
# 	segmentation (0.06958393113342898)
# 	knowledge (0.13163558106169296)
# 	detection (0.11800573888091823)
# 	convolutional (0.11836441893830703)
# 	different (0.266857962697274)
# 	information (0.25251076040172166)
# 	recognition (0.1330703012912482)
#
# Some Statistics words are:
# 	variational (0.10288270377733598)
# 	variables (0.14314115308151093)
# 	stochastic (0.1386679920477137)
# 	theoretical (0.15009940357852883)
# 	statistical (0.15109343936381708)
# 	distribution (0.17892644135188868)
# 	estimation (0.18538767395626243)
# 	inference (0.20228628230616302)
# 	dimensional (0.18836978131212723)
# 	regression (0.18290258449304175)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="abd4dd54-79f0-4189-8b0e-d470ef29a20e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("abd4dd54-79f0-4189-8b0e-d470ef29a20e")) {                    Plotly.newPlot(                        "abd4dd54-79f0-4189-8b0e-d470ef29a20e",                        [{"x":["introduction","disentangled","approaches","particular","conditional","distribution","development","independent","therefore","intrinsic","effectiveness","describing","different","corresponding","generation","attributes","demonstrate","variations","underlying","variational","dimensional","generalize","structured","realistic","represents","categorical","assumption","generative","observation","potentially","experiment","supervision","adversarial","generating","categories","projections","instances","densities","directional","inference","permutation","establishing","probability","embedding","demonstration","considered","impractical","procedure","factorial","polynomial","difficulty","developed","definition","permutations","statistics","continuous","framework","distributions","applications","multinomial","representation","hypersphere","criterion","surprising","differences","establish","parametrization","including","discrepancy","wasserstein","guarantees","distances","algorithms","geometrical","approximate","parametric","convergence","generator","geometries","interesting","nonconvex","arbitrary","synthetic","distributed","availability","implementation","specified","robustness","illustrate","procedures","characteristics","simulator","parameters","minimalistic","microscopy","discriminator","representations","encourages","hierarchical","gradually","introduce","leveraging","represent","independently","inception","information","encourage","introduced","maximizes","conditioned","decomposes","discriminative","uncertainties","inspection","hierarchy","artificial","preserving","observations","available","stochastic","randomised","functions","generalisation","augmentation","technique","overfitting","effectively","distortions","practices","augmented","expansion","constructed","efficient","constraint","construct","segmented","effective","redundant","overcomes","partitioning","dimensions","neighborhood","structure","clustering","requirement","generated","specifically","computation","consequently","situation","seemingly","subsequently","generates","additional","automatically","occurring","previously","generally","beautiful","identified","vectorial","straightforward","collections","relationship","meaningfully","collection","generalization","traditional","embeddings","representing","reproducing","techniques","accomplish","experimental","prediction","resources","restricted","complexity","typically","mechanism","sequences","classical","preferred","attention","symmetric","regularization","popularity","satisfies","considerable","knowledge","regression","compressed","necessary","completion","parameter","semidefinite","conditions","simplicity","estimation","tomography","promoting","constrained","measurements","similarity","similarities","reconstructing","obtaining","recovered","applicable","scientific","networking","significantly","expectation","significant","reconstruct","disciplines","relations","dependencies","experiments","disambiguation","structural","complementary","capabilities","probabilistic","important","enrichment","syntactic","corresponds","theoretical","motivates","borrowing","optimization","algorithm","necessity","minibatch","superiority","practical","reduction","computational","intersection","combining","experimentation","handwritten","classifier","histogram","extraction","recognition","character","recognized","devnagari","characters","classification","contextual","answering","retrieval","selection" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	cytometry
# 	homoscedastic
# 	advocates
# 	vulnerability
# 	retention
# 	semiparametric
# 	phenotype
# 	synchronously
# 	heckerman
# 	streamlined
# 	truncation
# 	blockmodels
# 	blockmodel
# 	parameterize
# 	covariate
# 	tremendously
# 	supercomputers
# 	retrospective
# 	neuroimaging
# 	subtleties
# Some words which never appear in Statistics papers:
# 	minimalistic
# 	disambiguation
# 	enrichment
# 	syntactic
# 	devnagari
# 	extrinsically
# 	travelling
# 	continued
# 	consisted
# 	reflection
# 	transmitted
# 	presently
# 	stakeholder
# 	supportive
# 	empathetic
# 	affection
# 	conversational
# 	interpersonal
# 	emotional
# 	entailment

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082329007798292e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
